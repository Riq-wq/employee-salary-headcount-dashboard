# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
df=pd.read_csv("C:/Users/Hassan/Desktop/POWERBI PROJECTS/employee salaries analysis/employee dataset.csv")

# %%
df
# Out:
#    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob   NaN  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu       NaN  18/02/2025
# 3           4    Alice  25.0  Nairobi   55000.0  15/01/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9      NaN  35.0   Kisumu   61000.0  05/05/2025
# 9          10   Hassan  28.0  Mombasa   58000.0  20/05/2025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  10 non-null     int64
#  1   Name        9 non-null      object
#  2   Age         9 non-null      float64
#  3   City        9 non-null      object
#  4   Salary      9 non-null      float64
#  5   JoinDate    10 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 612.0+ bytes

# %%
df = df.drop_duplicates(subset=["Name", "Age", "City", "Salary", "JoinDate"])

# %%
df.dtypes
# Out:
# EmployeeID      int64
# Name           object
# Age           float64
# City           object
# Salary        float64
# JoinDate       object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob   NaN  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu       NaN  18/02/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9      NaN  35.0   Kisumu   61000.0  05/05/2025
# 9          10   Hassan  28.0  Mombasa   58000.0  20/05/2025>

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          1
# Age           1
# City          1
# Salary        1
# JoinDate      0
# dtype: int64

# %%
df["Name"]=(df["Name"].fillna("Unknown"))
df
# Out:
# C:\Users\Hassan\AppData\Local\Temp\ipykernel_20140\339599648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"]=(df["Name"].fillna("Unknown"))
#    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob   NaN  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu       NaN  18/02/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9  Unknown  35.0   Kisumu   61000.0  05/05/2025
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df
# Out:
# C:\Users\Hassan\AppData\Local\Temp\ipykernel_20140\2535964098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].fillna(df["Age"].median())
#    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob  28.5  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu       NaN  18/02/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9  Unknown  35.0   Kisumu   61000.0  05/05/2025
# ...

# %%
df["Name"] = df["Name"].replace("Unknown", "Jamal")
df
# Out:
# C:\Users\Hassan\AppData\Local\Temp\ipykernel_20140\2924290035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"] = df["Name"].replace("Unknown", "Jamal")
#    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob  28.5  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu       NaN  18/02/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9    Jamal  35.0   Kisumu   61000.0  05/05/2025
# ...

# %%
df["Salary"]=df["Salary"].fillna(df["Salary"].median())
df
# Out:
# C:\Users\Hassan\AppData\Local\Temp\ipykernel_20140\775250596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Salary"]=df["Salary"].fillna(df["Salary"].median())
#    EmployeeID     Name   Age     City    Salary    JoinDate
# 0           1    Alice  25.0  Nairobi   55000.0  15/01/2025
# 1           2      Bob  28.5  Mombasa   62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu   59500.0  18/02/2025
# 4           5    Diana  31.0      NaN   70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru   48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret   51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  900000.0  18/04/2025
# 8           9    Jamal  35.0   Kisumu   61000.0  05/05/2025
# ...

# %%
df["City"].mode()
# Out:
# 0     Kisumu
# 1    Mombasa
# 2    Nairobi
# Name: City, dtype: object

# %%
df.loc[:, "City"] = df["City"].fillna(df["City"].mode()[0])

# %%
plt.boxplot(df["Salary"].dropna())
plt.title("Boxplot of Salary")
plt.show()

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Salary"] < lower) | (df["Salary"] > upper)]
outliers
# Out:
#    EmployeeID    Name   Age     City    Salary    JoinDate
# 7           8  George  40.0  Nairobi  900000.0  18/04/2025

# %%
df.loc[df["Name"] == "George", "Salary"] = 90000
df
# Out:
#    EmployeeID     Name   Age     City   Salary    JoinDate
# 0           1    Alice  25.0  Nairobi  55000.0  15/01/2025
# 1           2      Bob  28.5  Mombasa  62000.0  10/02/2025
# 2           3  Charlie  29.0   Kisumu  59500.0  18/02/2025
# 4           5    Diana  31.0   Kisumu  70000.0  01/03/2025
# 5           6     Evan  27.0   Nakuru  48000.0  15/03/2025
# 6           7    Faith  -5.0  Eldoret  51000.0  02/04/2025
# 7           8   George  40.0  Nairobi  90000.0  18/04/2025
# 8           9    Jamal  35.0   Kisumu  61000.0  05/05/2025
# 9          10   Hassan  28.0  Mombasa  58000.0  20/05/2025

# %%
import numpy as np

df.loc[df["Age"] < 0, "Age"] = np.nan
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df = df.drop_duplicates(subset=["Name", "Age", "City", "Salary", "JoinDate"]).copy()

# %%
df.loc[:, "JoinDate"] = pd.to_datetime(df["JoinDate"], dayfirst=True)

# %%
df["Age"] = df["Age"].fillna(df["Age"].median()).round().astype(int)
df
# Out:
#    EmployeeID     Name  Age     City   Salary             JoinDate
# 0           1    Alice   25  Nairobi  55000.0  2025-01-15 00:00:00
# 1           2      Bob   28  Mombasa  62000.0  2025-02-10 00:00:00
# 2           3  Charlie   29   Kisumu  59500.0  2025-02-18 00:00:00
# 4           5    Diana   31   Kisumu  70000.0  2025-03-01 00:00:00
# 5           6     Evan   27   Nakuru  48000.0  2025-03-15 00:00:00
# 6           7    Faith   29  Eldoret  51000.0  2025-04-02 00:00:00
# 7           8   George   40  Nairobi  90000.0  2025-04-18 00:00:00
# 8           9    Jamal   35   Kisumu  61000.0  2025-05-05 00:00:00
# 9          10   Hassan   28  Mombasa  58000.0  2025-05-20 00:00:00

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:0806@localhost/employee_db"
)

# %%
df.to_sql(
    "employees",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 9
